# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
df=pd.read_csv("Student_Performance.csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.T
# Out:
#                                   0     1     2     3     4     5     6     \
# Hours Studied                        7     4     8     5     7     3     7
# Previous Scores                     99    82    51    52    75    78    73
# Extracurricular Activities         Yes    No   Yes   Yes    No    No   Yes
# Sleep Hours                          9     4     7     5     8     9     5
# Sample Question Papers Practiced     1     2     2     2     5     6     6
# Performance Index                 91.0  65.0  45.0  36.0  66.0  61.0  63.0
#
#                                   7     8     9     ...  9990  9991  9992  \
# Hours Studied                        8     5     4  ...     9     5     9
# Previous Scores                     45    77    89  ...    43    97    52
# Extracurricular Activities         Yes    No    No  ...    No   Yes    No
# Sleep Hours                          4     8     4  ...     7     7     9
# ...

# %%
df.sample().T
# Out:
#                                   1009
# Hours Studied                        8
# Previous Scores                     88
# Extracurricular Activities          No
# Sleep Hours                          7
# Sample Question Papers Practiced     4
# Performance Index                 82.0

# %%
df.sample(5)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9897              6               51                        Yes            9
# 2205              3               88                         No            8
# 9552              7               77                         No            5
# 945               5               78                        Yes            5
# 5977              4               41                         No            6
#
#       Sample Question Papers Practiced  Performance Index
# 9897                                 9               42.0
# 2205                                 6               71.0
# 9552                                 9               70.0
# 945                                  5               64.0
# 5977                                 5               24.0

# %%
df.sample()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 7612              9               42                        Yes            6
#
#       Sample Question Papers Practiced  Performance Index
# 7612                                 3               38.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for col in df.columns:
    if df[col].dtype == object:
        df[col] = le.fit_transform(df[col])

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
for col in df:
    if col != "Performance Index" :
        sb.histplot(data=df , x=col , kde=True , palette="dark")
        plt.title(f"Distribution {col} " , color="black")
        plt.xlabel(col , color="red")
        plt.grid(True , linestyle="--" , alpha=0.5)
        plt.show()
# Out:
# C:\Users\xxonu\AppData\Local\Temp\ipykernel_11244\3953629870.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sb.histplot(data=df , x=col , kde=True , palette="dark")
# C:\Users\xxonu\AppData\Local\Temp\ipykernel_11244\3953629870.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sb.histplot(data=df , x=col , kde=True , palette="dark")
# C:\Users\xxonu\AppData\Local\Temp\ipykernel_11244\3953629870.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sb.histplot(data=df , x=col , kde=True , palette="dark")
# C:\Users\xxonu\AppData\Local\Temp\ipykernel_11244\3953629870.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sb.histplot(data=df , x=col , kde=True , palette="dark")
# C:\Users\xxonu\AppData\Local\Temp\ipykernel_11244\3953629870.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
# ...

# %%
df["Performance Index"].agg({"Hours Studied" : "mean"})
# Out:
# Hours Studied    55.2248
# Name: Performance Index, dtype: float64

# %%
df["Performance Index"].mean()
# Out:
# 55.2248

# %%
plt.figure(figsize=(8,8))
sb.heatmap(data=df.corr() , annot=True , cmap="coolwarm")
# Out:
# <Axes: >

# %%
df["Sleep Hours"].value_counts().plot(kind="pie" , autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sleep Hours"].value_counts().sort_values(ascending=True).plot(kind="line")
# Out:
# <Axes: xlabel='Sleep Hours'>

# %%
df.groupby("Sleep Hours")["Performance Index"].value_counts().unstack()
# Out:
# Performance Index  10.0   11.0   12.0   13.0   14.0   15.0   16.0   17.0   \
# Sleep Hours
# 4                    NaN    2.0    2.0    7.0    NaN    7.0    4.0    8.0
# 5                    1.0    NaN    1.0    3.0    4.0    4.0    2.0    9.0
# 6                    NaN    1.0    1.0    NaN    NaN    3.0    7.0    6.0
# 7                    NaN    1.0    3.0    NaN    2.0    2.0    5.0    3.0
# 8                    NaN    NaN    NaN    2.0    NaN    6.0    5.0    5.0
# 9                    NaN    1.0    1.0    1.0    1.0    4.0    7.0    4.0
#
# Performance Index  18.0   19.0   ...  91.0   92.0   93.0   94.0   95.0   \
# Sleep Hours                      ...
# 4                   12.0    7.0  ...    5.0    3.0    3.0    3.0    3.0
# 5                    9.0    7.0  ...    8.0    4.0    5.0    3.0    3.0
# 6                    7.0    8.0  ...    6.0    4.0    6.0    5.0    4.0
# 7                    7.0    6.0  ...    6.0    4.0    9.0    4.0    7.0
# ...

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %% [markdown]
# <div style="background-color: Green; padding: 16px; border: 2px white; color: white; font-size:29px;">
#      Tensorflow Model
#
#
# </div>

# %%
y=df["Performance Index"].values
x=df.drop("Performance Index" , axis=1).values

# %%
y
# Out:
# array([91., 65., 45., ..., 74., 95., 64.])

# %%
x
# Out:
# array([[ 7, 99,  1,  9,  1],
#        [ 4, 82,  0,  4,  2],
#        [ 8, 51,  1,  7,  2],
#        ...,
#        [ 6, 83,  1,  8,  5],
#        [ 9, 97,  1,  7,  0],
#        [ 7, 74,  0,  8,  1]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.12,random_state=1234)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train.shape
# Out:
# (8800, 5)

# %%
x_test.shape
# Out:
# (1200, 5)

# %%
y_train
# Out:
# array([47., 31., 28., ..., 67., 73., 85.])

# %%
x_test
# Out:
# array([[0.375     , 0.77966102, 0.        , 0.6       , 0.        ],
#        [1.        , 1.        , 1.        , 0.        , 0.88888889],
#        [0.375     , 0.93220339, 0.        , 0.4       , 0.77777778],
#        ...,
#        [0.5       , 0.89830508, 1.        , 0.8       , 0.66666667],
#        [0.625     , 0.50847458, 0.        , 0.4       , 0.88888889],
#        [0.875     , 0.37288136, 0.        , 0.        , 0.33333333]])

# %%
 import tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
tensorModel = Sequential()

# %%
tensorModel.add(Dense(5,activation="relu"))
tensorModel.add(Dense(64,activation="relu"))
tensorModel.add(Dense(2,activation="relu"))
tensorModel.add(Dense(1))

tensorModel.compile(optimizer="adam" , loss="mse" , metrics=["mae"])

# %%
tensorModel.fit(x=x_train,y=y_train , epochs=200,verbose=1,validation_data=(x_test,y_test))
# Out:
# Epoch 1/200
# 275/275 [==============================] - 2s 2ms/step - loss: 1980.4120 - mae: 38.0713 - val_loss: 176.6261 - val_mae: 10.8166
# Epoch 2/200
# 275/275 [==============================] - 0s 1ms/step - loss: 139.4867 - mae: 9.6742 - val_loss: 95.1516 - val_mae: 7.9802
# Epoch 3/200
# 275/275 [==============================] - 0s 1ms/step - loss: 65.8758 - mae: 6.6598 - val_loss: 36.4027 - val_mae: 4.9561
# Epoch 4/200
# 275/275 [==============================] - 0s 1ms/step - loss: 21.5802 - mae: 3.7572 - val_loss: 10.3727 - val_mae: 2.5957
# Epoch 5/200
# 275/275 [==============================] - 0s 1ms/step - loss: 7.3962 - mae: 2.1626 - val_loss: 5.1859 - val_mae: 1.8110
# Epoch 6/200
# 275/275 [==============================] - 0s 1ms/step - loss: 4.8792 - mae: 1.7486 - val_loss: 4.2899 - val_mae: 1.6478
# Epoch 7/200
# 275/275 [==============================] - 0s 1ms/step - loss: 4.4072 - mae: 1.6646 - val_loss: 4.1020 - val_mae: 1.6125
# Epoch 8/200
# ...

# %%
modelPlot=pd.DataFrame(tensorModel.history.history)

# %%
tensorModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 64)                384
#
#  dense_2 (Dense)             (None, 2)                 130
#
#  dense_3 (Dense)             (None, 1)                 3
#
# ...
# Total params: 547
# Trainable params: 547
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelPlot.plot()
# Out:
# <Axes: >

# %%
tensorModel.evaluate(x_test,y_test)
# Out:
# 38/38 [==============================] - 0s 1ms/step - loss: 4.0494 - mae: 1.6063
# [4.049382209777832, 1.606299877166748]

# %%
prediction=tensorModel.predict(x_test)
# Out:
# 38/38 [==============================] - 0s 1ms/step

# %%
prediction
# Out:
# array([[68.69595 ],
#        [96.881645],
#        [78.78904 ],
#        ...,
#        [80.95054 ],
#        [59.14157 ],
#        [54.60818 ]], dtype=float32)

# %%
print(r2_score(prediction,y_test))
# Out:
# 0.9886728443986303

# %%
print(mean_absolute_error(prediction,y_test))
print(mean_squared_error(prediction,y_test))
# Out:
# 1.606299950281779
# 4.049382294781628

# %% [markdown]
# <div style="background-color: Green; padding: 16px; border: 2px white; color: white; font-size:29px;">
#      Tensorflow Model  Prediction vs Test Data
#
#
# </div>

# %%
plt.figure(figsize=(9,5.5))
plt.scatter(y_test,prediction)
plt.plot(y_test,y_test,color="red")
plt.title("Prediction Efficency")
plt.grid(alpha=0.8,linestyle="--")
plt.savefig(f"Tensor_Model_Graph.png")
plt.show()

# %% [markdown]
# <div style="background-color: Green; padding: 16px; border: 2px white; color: white; font-size:29px;">
#      Making Model the predict a data.
#     It comes very accurate as just 0.36 deviation
#
#
# </div>

# %%
df.iloc[31]
# Out:
# Hours Studied                        7.0
# Previous Scores                     44.0
# Extracurricular Activities           1.0
# Sleep Hours                          9.0
# Sample Question Papers Practiced     1.0
# Performance Index                   36.0
# Name: 31, dtype: float64

# %%
newGradetest=df.drop("Performance Index" , axis=1).iloc[31]

# %%
newGradetest=scaler.transform(newGradetest.values.reshape(-1,5))

# %%
tensorModel.predict(newGradetest)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# array([[36.01188]], dtype=float32)

# %% [markdown]
# <div style="background-color: Green; padding: 16px; border: 2px white; color: white; font-size:29px;">
#      Sklearn Models
#
#
# </div>

# %%
from sklearn.linear_model import LinearRegression

# %%
linearModel=LinearRegression()

# %%
linearModel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictionLinear=linearModel.predict(x_test)

# %%
print(r2_score(predictionLinear,y_test))
# Out:
# 0.9888891186051645

# %%
from sklearn.ensemble import RandomForestRegressor
RandomForest_model=RandomForestRegressor()

# %%
RandomForest_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
predictionRandomForest=RandomForest_model.predict(x_test)

# %%
r2result= r2_score(predictionRandomForest,y_test)
